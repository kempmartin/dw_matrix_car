# %%
# !pip install --upgrade tables
# Out:
# Collecting tables
#   Downloading https://files.pythonhosted.org/packages/ed/c3/8fd9e3bb21872f9d69eb93b3014c86479864cca94e625fd03713ccacec80/tables-3.6.1-cp36-cp36m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 2.7MB/s
# Requirement already satisfied, skipping upgrade: numexpr>=2.6.2 in /usr/local/lib/python3.6/dist-packages (from tables) (2.7.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.3 in /usr/local/lib/python3.6/dist-packages (from tables) (1.17.5)
# Installing collected packages: tables
#   Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# Successfully installed tables-3.6.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import  seaborn as sns

# %%
cd "/content/drive/My Drive/Colab Notebooks/ml_matrix/matrix_two/dw_matrix_car"
# Out:
# /content/drive/My Drive/Colab Notebooks/ml_matrix/matrix_two/dw_matrix_car

# %%
df = pd.read_hdf('data/car.h5')
df.shape
# Out:
# (106494, 155)

# %%
df['price_value'].hist(bins=100)

# %%
df['price_value'].describe()
df['param_marka-pojazdu'].describe()
# Out:
# count         106302
# unique           100
# top       Volkswagen
# freq           11314
# Name: param_marka-pojazdu, dtype: object

# %%
(
  df
  .groupby('param_marka-pojazdu')['price_value']
  .agg([np.mean, np.median, np.size])
  .sort_values(by='size', ascending=False)
  .head(50)
  .plot(kind='bar', figsize=(15,5), subplots=True)
)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fbac9c6cc88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbac9bdde80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbac9b8f320>],
#       dtype=object)

# %%
def group_and_barplot(feat_groupby, feat_agg='price_value', agg_funcs=[np.mean, np.median, np.size], feat_sort='mean', top=50, subplots=True):
  return (
    df
    .groupby(feat_groupby)[feat_agg]
    .agg(agg_funcs)
    .sort_values(by=feat_sort, ascending=False)
    .head(top)
    .plot(kind='bar', figsize=(15,5), subplots=subplots)
)

# %%
group_and_barplot('param_marka-pojazdu');

# %%
group_and_barplot('param_country-of-origin');
group_and_barplot('param_kraj-pochodzenia');

# %%
# !git add day
