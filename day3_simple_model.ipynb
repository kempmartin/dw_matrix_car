# %%
# !pip install --upgrade tables
# !pip install eli5
# Out:
# ...
#      |████████████████████████████████| 4.3MB 2.8MB/s
# ...
#   Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# ...
#      |████████████████████████████████| 112kB 2.7MB/s
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.dummy import DummyRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error as mae
from sklearn.model_selection import cross_val_score
import eli5

from eli5.sklearn import PermutationImportance

# %% [markdown]
# ##Data adding

# %%
cd "/content/drive/My Drive/Colab Notebooks/ml_matrix/matrix_two/dw_matrix_car"
# Out:
# /content/drive/My Drive/Colab Notebooks/ml_matrix/matrix_two/dw_matrix_car

# %%
df = pd.read_hdf('data/car.h5')

# %% [markdown]
# ## Dummy Model

# %%
df.select_dtypes(np.number).columns
# Out:
# Index(['price_value', 'car_id'], dtype='object')

# %%
feats = ['car_id']
X = df[feats].values
y = df['price_value'].values

model = DummyRegressor()
model.fit(X, y)
y_pred = model.predict(X)

mae(y, y_pred)
# Out:
# 39465.934630440985

# %%
df = df[df['price_currency'] != 'EUR']

# %%
df['price_currency'].value_counts()
# Out:
# PLN    106290
# Name: price_currency, dtype: int64

# %%
SUFFIX_CAT = '__cat'
for feat in df.columns:
  if isinstance(df[feat][0], list):continue

  factorized_valeus = df[feat].factorize()[0]
  if SUFFIX_CAT in feat:
    df[feat] = factorized_valeus
  else:
    df[feat + SUFFIX_CAT] = factorized_valeus

# %%
df['param_color'].factorize()[0]
# Out:
# array([-1, -1, -1, ..., -1, -1, -1])

# %%
cat_feats = [x for x in df.columns if SUFFIX_CAT in x]
cat_feats = [x for x in cat_feats if 'price' not in x]
cat_feats
# Out:
# ['created_at__cat',
#  'seller_address__cat',
#  'seller_name__cat',
#  'seller_type__cat',
#  'feature_czujniki-parkowania-przednie__cat',
#  'feature_poduszka-powietrzna-chroniąca-kolana__cat',
#  'feature_kurtyny-powietrzne__cat',
#  'feature_klimatyzacja-dwustrefowa__cat',
#  'feature_światła-led__cat',
#  'feature_czujnik-zmierzchu__cat',
#  'feature_elektrycznie-ustawiane-lusterka__cat',
#  'feature_asr-(kontrola-trakcji)__cat',
#  'feature_poduszka-powietrzna-kierowcy__cat',
#  'feature_cd__cat',
#  'feature_elektryczne-szyby-przednie__cat',
#  'feature_poduszka-powietrzna-pasażera__cat',
#  'feature_system-start-stop__cat',
#  'feature_światła-do-jazdy-dziennej__cat',
#  'feature_komputer-pokładowy__cat',
#  'feature_elektryczne-szyby-tylne__cat',
#  'feature_klimatyzacja-manualna__cat',
#  'feature_tapicerka-welurowa__cat',
#  'feature_czujnik-deszczu__cat',
#  'feature_światła-przeciwmgielne__cat',
#  'feature_ogrzewanie-postojowe__cat',
# ...

# %%
X = df[cat_feats].values
y = df['price_value'].values

model = DecisionTreeRegressor(max_depth=5)
scores  = cross_val_score(model, X, y, cv=3, scoring='neg_mean_absolute_error')
np.mean(scores)
# Out:
# -19566.588937368328

# %%
model2 = DecisionTreeRegressor(max_depth=5)
model2.fit(X,y)

imp = PermutationImportance(model2, random_state=0).fit(X,y)
eli5.show_weights(imp, feature_names=cat_feats)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2533
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_napęd__cat
#             </td>
# ...

# %%
# !git config --global user.email "daniel.lesniewski@gmail.com"
# !git config --global user.name "DanielL"

# %%
# !git add day3_simple_model.ipynb
# Out:
# fatal: pathspec 'day3_simple_model.ipynb' did not match any files

# %%
ls
